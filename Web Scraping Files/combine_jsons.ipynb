# %%
import pandas as pd
import json

# %%
# read data from jsons
data1 = pd.read_json("perfume_data.json") 
data2 = pd.read_json("perfume_data_2017_plus.json") 
data3 = pd.read_json("perfume_data_2020_2021_45_hits_REM.json")

# %%
# combine all jsons into one df
data_combined = pd.concat([data1, data2, data3], ignore_index=True)

# %%
data_combined2 = data_combined.copy()
data_combined2
# Out:
#                          name             company  \
# 0               Angels' Share           By Kilian
# 1                      My Way      Giorgio Armani
# 2               Libre Intense  Yves Saint Laurent
# 3             Dior Homme 2020      Christian Dior
# 4       Acqua di Giò Profondo      Giorgio Armani
# ..                        ...                 ...
# 230           1 Million Lucky        Paco Rabanne
# 231          Midnight Fantasy      Britney Spears
# 232  Shock-In-Scent For Women              Police
# 233                Rose Prick            Tom Ford
# 234    Fantasy The Nice Remix      Britney Spears
#
#                                                  image         for_gender  \
# 0    https://fimgs.net/mdimg/perfume/375x500.62615.jpg  for women and men
# 1    https://fimgs.net/mdimg/perfume/375x500.62036.jpg          for women
# 2    https://fimgs.net/mdimg/perfume/375x500.62318.jpg          for women
# ...

# %%
# remove duplicates by perfume name 
data_combined2.drop_duplicates(subset=['name'], inplace=True)

# %%
data_combined2
# Out:
#                                             name             company  \
# 0                                  Angels' Share           By Kilian
# 1                                         My Way      Giorgio Armani
# 2                                  Libre Intense  Yves Saint Laurent
# 3                                Dior Homme 2020      Christian Dior
# 4                          Acqua di Giò Profondo      Giorgio Armani
# ..                                           ...                 ...
# 184                                Instant Crush             Mancera
# 185           Mon Guerlain Eau de Parfum Intense            Guerlain
# 186                                     Sì Fiori      Giorgio Armani
# 187                            Gabrielle Essence              Chanel
# 188  Emporio Armani Stronger With You Intensely       Giorgio Armani
#
#                                                  image         for_gender  \
# ...

# %%
data_combined2_dict = data_combined2.to_dict()

# %%
with open ("perfume_data_combined_20200228.json", "w") as f:
    json.dump(data_combined2_dict, f)
